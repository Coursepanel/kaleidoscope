# %% [markdown]
# ## Setting up Open AI Connection

# %%
# !pip install -U openai pinecone-client datasets pandas numpy tiktoken sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.4-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 2.9 MB/s eta 0:00:00
# Collecting pinecone-client
#   Downloading pinecone_client-2.2.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 8.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Collecting pandas
#   Downloading pandas-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (1.22.4)
# Collecting numpy
#   Downloading numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 73.4 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.0 MB/s eta 0:00:00
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from pinecone-client) (1.26.15)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.9/dist-packages (from pinecone-client) (4.5.0)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.9/dist-packages (from pinecone-client) (6.0)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.9/dist-packages (from pinecone-client) (2.8.2)
# Collecting loguru>=0.5.0
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 14.3 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 19.7 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.9/dist-packages (from tiktoken) (2022.10.31)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 15.4 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 12.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.10.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2955 sha256=2c557848efea6d81fad11348260c6bda314e49fa844d6856778f44a3983e4bab
#   Stored in directory: /root/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# Installing collected packages: sklearn, xxhash, numpy, multidict, loguru, frozenlist, dnspython, dill, async-timeout, yarl, tiktoken, responses, pinecone-client, pandas, multiprocess, huggingface-hub, aiosignal, aiohttp, openai, datasets
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 dnspython-2.3.0 frozenlist-1.3.3 huggingface-hub-0.13.4 loguru-0.7.0 multidict-6.0.4 multiprocess-0.70.14 numpy-1.24.2 openai-0.27.4 pandas-2.0.0 pinecone-client-2.2.1 responses-0.18.0 sklearn-0.0.post1 tiktoken-0.3.3 xxhash-3.2.0 yarl-1.8.2

# %%
## Constants

OPENAI_API_KEY = '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'

# %%
import openai
openai.api_key = OPENAI_API_KEY
# get API key from top-right dropdown on OpenAI website

# openai.Engine.list()  # check we have authenticated

# %%
MODEL = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        "Sample document text goes here",
        "there will be several phrases in each batch"
    ], engine=MODEL
)

# %%
# extract embeddings to a list
embeds = [record['embedding'] for record in res['data']]

# %% [markdown]
# ## Converting CSV data into embeddings

# %%
import pandas as pd

csv_url = 'https://docs.google.com/spreadsheets/d/10xvFQVZdRxfxCS1of71mN0akur-9e7lsM8yEogZCrMs/pub?gid=0&single=true&output=csv'

# Load the CSV data
# data = pd.read_csv(csv_url)
data = pd.read_csv('/content/course-ner-data.csv')
data = data.fillna('')
data.head(5)

# Combine important text info into 1 column

data['text'] = data['name'] + data['tags']
# Set the maximum allowed length for a given column
max_length = 16384
column_name = 'text'

# Truncate the values in the specified column
data[column_name] = data[column_name].apply(lambda x: x[:max_length] if len(x) > max_length else x)

# %%
# def get_embeddings(texts, model="text-davinci-002"):
#     embeddings = []
#     batch_size = 128

#     for i in range(0, len(texts), batch_size):
#         batch_texts = texts[i:i + batch_size]
#         prompt = "\n".join(batch_texts)
#         completions = openai.Completion.create(
#             engine=model,
#             prompt=prompt,
#             max_tokens=22,
#             n=len(batch_texts),
#             stop=None,
#             temperature=0,
#             logprobs=0,
#             echo=True
#         )
#         # batch_embeddings = [completion['choices'][0]['embeddings']['mean'] for completion in completions['choices']]
#         # embeddings.extend(batch_embeddings)
#         print(completions)

#     return embeddings

# # Generate embeddings for the courses
# embeddings = get_embeddings(data['text'])

def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

data['ada_embedding'] = data['text'].apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))

# %%
data['ada_embedding'].head()
# Out:
# 0    [0.01963328756392002, 0.010710296221077442, 0....
# 1    [0.009129764512181282, 0.0003475684206932783, ...
# 2    [-0.009399139322340488, 0.007830390706658363, ...
# 3    [-0.0007247348548844457, 0.00911095179617405, ...
# 4    [-0.028600748628377914, -0.019169151782989502,...
# Name: ada_embedding, dtype: object

# %%
data.to_csv('embedded_data.csv', index=False)

# %% [markdown]
# ## Calculate similarity between courses

# %%
import tiktoken

def count_tokens(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

count_tokens("tiktoken is great!", "cl100k_base")
# Out:
# 6

# %%
embeddings = data['ada_embedding']

# %%
import numpy as np

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
def find_similar_courses(course_id, embeddings, threshold=0.5):
    target_embedding = embeddings[course_id]
    similarities = []

    for idx, embedding in enumerate(embeddings):
        if idx == course_id:
            continue
        
        similarity = cosine_similarity(target_embedding, embedding)
        
        if similarity > threshold:
            similarities.append((idx, similarity))

    # Sort by similarity score
    similarities.sort(key=lambda x: x[1], reverse=True)

    return similarities

# %%
course_id = 3  # Replace with the desired course ID
similar_courses = find_similar_courses(course_id, embeddings)

# print(f"Similar courses for course ID {course_id}:")
# for idx, similarity in similar_courses:
#     print(f"Course ID: {idx}, Similarity: {similarity:.3f}")
# Out:
# Similar courses for course ID 3:

# %%
top_matches = [t[1] for t in similar_courses[:5]]
top_matches_idxs = [t[0] for t in similar_courses[:5]]
selected_rows_df = data.iloc[top_matches_idxs]
selected_rows_df
# Out:
#                             id
# 985   6265b98c2dec4c36901ee8a9  \
# 265   6265b9922dec4c36901ee939
# 1967  6265b9952dec4c36901ee993
# 1758  6265b98d2dec4c36901ee8bf
# 23    6265b9922dec4c36901ee943
#
#                                           courseContent
# 985   Principles of power flow control and voltage c...  \
# 265   Introduction to AC and DC microgrid systems, d...
# 1967  ) Power Converters, • Introduction, DC-DC Conv...
# 1758  Principles of Drives, Drive train methods – Ge...
# 23    Introduction to Power Systems: Historical deve...
#
#                      prerequisitesOfCurrentCourse
# 985                                                \
# 265   B. Tech./DD with power electronics (EE3203)
# 1967
# 1758      POWER ELECTRONICS for BTech/DD students
# 23                                         EE2005
#
#                                          referenceBooks
# 985   1. \tUnderstanding FACTS – Concepts and Techno...  \
# 265   1 Sudipta Chakraborty, Marcelo G. Simões, and ...
# 1967  1) Issa Batarseh, Power Electronic Circuits, J...
# 1758  3.\tR. Krishnan, “Electric Motor Drives: Model...
# 23    1.\tElectrical energy systems theory an introd...
#
#                                               textBooks
# 985   1.\tFACTS Controllers in Power Transmission an...  \
# 265   S.P. Chowdhury, P. Crossley, S. Chowdhury \Mic...
# 1967  1) R. W. Erickson and D. Maksimovic, “Fundamen...
# 1758  1.\tW. Leonhard, Control of Electrical Drives,...
# 23    1.\tPower system Analysis: John J. Grainger an...
#
#      extractedPrereqCourseCodes slots courseCode courseType  credits deptCode
# 985                                       EE5261     Theory        9       EE  \
# 265                      EE3203           EE5262     Theory        9       EE
# 1967                                G     EE5203     Theory        9       EE
# 1758                                      EE6200     Theory        9       EE
# 23                       EE2005           EE3003     Theory       10       EE
#
#                                             description
# 985   1.\tTo expose the students to an emerging tech...  \
# 265   This course is a graduate level course for Ele...
# 1967  To familiarise students with the techniques of...
# 1758  This course is a graduate level course for Ele...
# 23    This course is a first course on power systems...
#
#                                                    name
# 985             Flexible AC Transmission Systems-EE5261  \
# 265   Distributed Generation and Microgrid Systems-E...
# 1967              Switched Mode Power Conversion-EE5203
# 1758  Power Electronic Control of Electric Machines-...
# 23                                 Power Systems-EE3003
#
#                                                    tags
# 985   Flexible AC Transmission Systems-EE5261; Princ...  \
# 265   Distributed Generation; Microgrid Systems; EE5...
# 1967  Power Converters; Introduction; DC-DC Converte...
# 1758  Principles of Drives; Drive train methods – Ge...
# 23    Power Systems; EE3003; Historical developments...
#
#                                                    text
# 985   Flexible AC Transmission Systems-EE5261Flexibl...  \
# 265   Distributed Generation and Microgrid Systems-E...
# 1967  Switched Mode Power Conversion-EE5203Power Con...
# 1758  Power Electronic Control of Electric Machines-...
# 23    Power Systems-EE3003Power Systems; EE3003; His...
#
#                                           ada_embedding
# 985   [-0.010727227665483952, -0.008826367557048798,...
# 265   [-0.00839999970048666, -0.011146278120577335, ...
# 1967  [-0.0075479368679225445, -0.003704992355778813...
# 1758  [-0.020906182006001472, -0.011193601414561272,...
# 23    [-0.0017959055257961154, -0.013223945163190365...

# %%
selected_rows_df = data.iloc[[3,985, 397, 1254]]
selected_rows_df
# Out:
#                             id
# 3     6265b9972dec4c36901ee9cb  \
# 985   6265b98c2dec4c36901ee8a9
# 397   6265b99a2dec4c36901eea17
# 1254  6265b9952dec4c36901ee989
#
#                                           courseContent
# 3     Historical Developments, Applications of DC Tr...  \
# 985   Principles of power flow control and voltage c...
# 397   Introduction to Protective Relays:  Basics and...
# 1254  Introduction to power systems stability proble...
#
#          prerequisitesOfCurrentCourse
# 3                                      \
# 985
# 397   EE3003 Electrical Power Systems
# 1254                              COT
#
#                                          referenceBooks
# 3     1. C. Adamson and N.G. Hingorani, High Voltage...  \
# 985   1. \tUnderstanding FACTS – Concepts and Techno...
# 397   1.\tLeslie Hewirson, Marl Brown, Ramesn Balakr...
# 1254  1. K. R. Padiyar, \Power systems dynamics: sta...
#
#                                               textBooks
# 3     1. E.W. Kimbark, Direct Current Transmission, ...  \
# 985   1.\tFACTS Controllers in Power Transmission an...
# 397   1.\tPaul M. Anderson “Power System Protection”...
# 1254  1. Peter W. Sauer and M. A. Pai, “Power system...
#
#      extractedPrereqCourseCodes slots courseCode courseType  credits deptCode
# 3                                   B     EE6258     Theory        9       EE  \
# 985                                       EE5261     Theory        9       EE
# 397                      EE3003     K     EE6255     Theory        9       EE
# 1254                                      EE6253     Theory        9       EE
#
#                                             description
# 3     1. To present a power transmission technology\...  \
# 985   1.\tTo expose the students to an emerging tech...
# 397   1. To understand the fundamentals and basics o...
# 1254  This course is an advanced level graduate cour...
#
#                                            name
# 3          DC Power Transmission Systems-EE6258  \
# 985     Flexible AC Transmission Systems-EE5261
# 397              Power System Protection-EE6255
# 1254  Power System Control and Stability-EE6253
#
#                                                    tags
# 3     Historical Developments; Applications of DC Tr...  \
# 985   Flexible AC Transmission Systems-EE5261; Princ...
# 397   Power System Protection-EE6255;Protective Rela...
# 1254  Power System Control and Stability-EE6253; Int...
#
#                                            text
# 3          DC Power Transmission Systems-EE6258  \
# 985     Flexible AC Transmission Systems-EE5261
# 397              Power System Protection-EE6255
# 1254  Power System Control and Stability-EE6253
#
#                                           ada_embedding
# 3     [-0.02118978649377823, -0.0140390545129776, -0...
# 985   [-0.005114557221531868, -0.004863351117819548,...
# 397   [-0.011694437824189663, -0.01351387333124876, ...
# 1254  [0.0002539408451411873, -0.016346782445907593,...

# %%
import pinecone

# initialize connection to pinecone (get API key at app.pinecone.io)
pinecone.init(
    api_key="c2f3c69c-4276-4df4-9a91-95409d65b127",
    environment="northamerica-northeast1-gcp"  # find next to API key in console
)

# check if 'openai' index already exists (only create index if not)
if 'openai' not in pinecone.list_indexes():
    pinecone.create_index('openai', dimension=len(embeds[0]))
# connect to index
index = pinecone.Index('openai')
# Out:
# /usr/local/lib/python3.9/dist-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from datasets import load_dataset

# load the first 1K rows of the TREC dataset
trec = load_dataset('trec', split='train[:1000]')
# Out:
# Downloading builder script:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading and preparing dataset trec/default to /root/.cache/huggingface/datasets/trec/default/2.0.0/f2469cab1b5fceec7249fda55360dfdbd92a7a5b545e91ea0f78ad108ffac1c2...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/336k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/23.4k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5452 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Dataset trec downloaded and prepared to /root/.cache/huggingface/datasets/trec/default/2.0.0/f2469cab1b5fceec7249fda55360dfdbd92a7a5b545e91ea0f78ad108ffac1c2. Subsequent calls will reuse this data.

# %%
from tqdm.auto import tqdm  # this is our progress bar

batch_size = 32  # process everything in batches of 32
for i in tqdm(range(0, len(data['text']), batch_size)):
    # set end position of batch
    i_end = min(i+batch_size, len(data['text']))
    # get batch of lines and IDs
    lines_batch = data['text'][i: i+batch_size]
    ids_batch = [str(n) for n in range(i, i_end)]
    # create embeddings
    res = openai.Embedding.create(input=lines_batch, engine=MODEL)
    embeds = [record['embedding'] for record in res['data']]
    # prep metadata and upsert batch
    meta = [{'text': line} for line in lines_batch]
    to_upsert = zip(ids_batch, embeds, meta)
    # upsert to Pinecone
    index.upsert(vectors=list(to_upsert))
